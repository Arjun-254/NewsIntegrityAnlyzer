# %%
from selenium import webdriver
from selenium.webdriver.common.by import By


driver = webdriver.Chrome()

# Get free proxies for rotating
def get_free_proxies(driver):
    driver.get('https://sslproxies.org')

    table = driver.find_element(By.TAG_NAME, 'table')
    thead = table.find_element(By.TAG_NAME, 'thead').find_elements(By.TAG_NAME, 'th')
    tbody = table.find_element(By.TAG_NAME, 'tbody').find_elements(By.TAG_NAME, 'tr')

    headers = []
    for th in thead:
        headers.append(th.text.strip())

    proxies = []
    for tr in tbody:
        proxy_data = {}
        tds = tr.find_elements(By.TAG_NAME, 'td')
        for i in range(len(headers)):
            proxy_data[headers[i]] = tds[i].text.strip()
        proxies.append(proxy_data)
    
    return proxies


free_proxies = get_free_proxies(driver)

print(free_proxies)
# Out:
# [{'IP Address': '212.92.148.164', 'Port': '8090', 'Code': 'RU', 'Country': 'Russian Federation', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '4 secs ago'}, {'IP Address': '212.92.148.162', 'Port': '8090', 'Code': 'RU', 'Country': 'Russian Federation', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '4 secs ago'}, {'IP Address': '203.189.88.156', 'Port': '80', 'Code': 'ID', 'Country': 'Indonesia', 'Anonymity': 'anonymous', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '12 secs ago'}, {'IP Address': '172.183.241.1', 'Port': '8080', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'elite proxy', 'Google': 'no', 'Https': 'yes', 'Last Checked': '12 secs ago'}, {'IP Address': '47.251.70.179', 'Port': '80', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'elite proxy', 'Google': 'no', 'Https': 'yes', 'Last Checked': '12 secs ago'}, {'IP Address': '199.168.175.179', 'Port': '80', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'elite proxy', 'Google': 'no', 'Https': 'yes', 'Last Checked': '12 secs ago'}, {'IP Address': '189.240.60.163', 'Port': '9090', 'Code': 'MX', 'Country': 'Mexico', 'Anonymity': 'elite proxy', 'Google': 'no', 'Https': 'yes', 'Last Checked': '10 mins ago'}, {'IP Address': '5.45.107.19', 'Port': '3128', 'Code': 'DE', 'Country': 'Germany', 'Anonymity': 'anonymous', 'Google': 'no', 'Https': 'yes', 'Last Checked': '21 mins ago'}, {'IP Address': '72.10.160.171', 'Port': '10095', 'Code': 'CA', 'Country': 'Canada', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '21 mins ago'}, {'IP Address': '189.240.60.164', 'Port': '9090', 'Code': 'MX', 'Country': 'Mexico', 'Anonymity': 'anonymous', 'Google': '', 'Https': 'yes', 'Last Checked': '30 mins ago'}, {'IP Address': '52.82.123.144', 'Port': '3128', 'Code': 'CN', 'Country': 'China', 'Anonymity': 'anonymous', 'Google': '', 'Https': 'yes', 'Last Checked': '30 mins ago'}, {'IP Address': '43.132.124.11', 'Port': '3128', 'Code': 'HK', 'Country': 'Hong Kong', 'Anonymity': 'anonymous', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '30 mins ago'}, {'IP Address': '47.252.29.28', 'Port': '11222', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '31 mins ago'}, {'IP Address': '35.185.196.38', 'Port': '3128', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'anonymous', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '40 mins ago'}, {'IP Address': '148.72.165.7', 'Port': '30135', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '40 mins ago'}, {'IP Address': '67.43.228.254', 'Port': '2679', 'Code': 'CA', 'Country': 'Canada', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '50 mins ago'}, {'IP Address': '47.90.205.231', 'Port': '33333', 'Code': 'US', 'Country': 'United States', 'Anonymity': 'anonymous', 'Google': 'no', 'Https': 'yes', 'Last Checked': '50 mins ago'}, {'IP Address': '8.223.31.16', 'Port': '80', 'Code': 'SG', 'Country': 'Singapore', 'Anonymity': 'anonymous', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '1 hour ago'}, {'IP Address': '160.86.242.23', 'Port': '8080', 'Code': 'JP', 'Country': 'Japan', 'Anonymity': 'elite proxy', 'Google': 'no', 'Https': 'yes', 'Last Checked': '1 hour ago'}, {'IP Address': '67.43.227.227', 'Port': '11023', 'Code': 'CA', 'Country': 'Canada', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '1 hour ago'}, {'IP Address': '72.10.160.174', 'Port': '13093', 'Code': 'CA', 'Country': 'Canada', 'Anonymity': 'elite proxy', 'Google': 'yes', 'Https': 'yes', 'Last Checked': '1 hour 11 mins ago'}, {'IP Address': '8.219.97.248', 'Port': '80', 'Code': 'SG', 'Country': 'Singapore', 'Anonymity': 'anonymous', 'Google': 'no', 'Https': 'yes', 'Last Checked': '1 hour 11 mins ago'}, {'IP Address': '213.230.124.108', 'Port': '8088', 'Code': 'UZ', 'Count ...
